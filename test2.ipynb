# %%
import pandas as pd


post_id = '123'
user_id = 'a'

df = pd.DataFrame({'post_id': ['123'], 'user_id': ['a']})
df = df.query("(user_id == @user_id) & (post_id == @post_id)")
print(df)


# for index, row in df.iterrows():
#     print(f"{index}, {row['A']}")

# print(df)
# Out:
# int64
